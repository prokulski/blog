# %%
library(tidyverse)
library(sf)
# Out:
# ── Attaching packages ───────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✓ ggplot2 3.3.0          ✓ purrr   0.3.3
# ✓ tibble  3.0.0          ✓ dplyr   0.8.5
# ✓ tidyr   1.0.2          ✓ stringr 1.4.0.9000
# ✓ readr   1.3.1.9000     ✓ forcats 0.5.0
#
# ── Conflicts ──────────────────────────────────────────── tidyverse_conflicts() ──
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
#
# Linking to GEOS 3.8.0, GDAL 3.0.4, PROJ 7.0.0

# %%
install.packages("geojsonio")
# Out:
# Installing package into ‘/home/lemur/R/x86_64-pc-linux-gnu-library/3.6’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘httpcode’, ‘protolite’, ‘crul’, ‘geojson’
#
#
# Warning message in install.packages("geojsonio"):
# “installation of package ‘protolite’ had non-zero exit status”
# Warning message in install.packages("geojsonio"):
# “installation of package ‘geojson’ had non-zero exit status”
# Warning message in install.packages("geojsonio"):
# “installation of package ‘geojsonio’ had non-zero exit status”

# %%
mapa = read_sf("../map_data/history_maps/Poland 1770-1978//Poland_1770_v.1.0.shp")

# %%
mapa
# Out:
# ERROR while rich displaying an object: Error in loadNamespace(name): there is no package called ‘geojsonio’
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# ...

# %%
ggplot(mapa) + geom_sf(aes(fill=NAME))
# Out:
# plot without title
